# %% [markdown]
# Download packages pydub (used to split and manipulate audio) and ffmpeg (allows you to edit audio)

# %%
# !pip install pydub
# Out:
# Requirement already satisfied: pydub in /Users/jenni/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (0.25.1)

# %%
# !brew install ffmpeg
# Out:
# ==> Auto-updating Homebrew...
# Adjust how often this is run with HOMEBREW_AUTO_UPDATE_SECS or disable with
# HOMEBREW_NO_AUTO_UPDATE. Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> Downloading https://ghcr.io/v2/homebrew/portable-ruby/portable-ruby/blobs/sha256:e7340e4a1d7cc0f113686e461b93114270848cb14676e9037a1a2ff3b1a0ff32
# ######################################################################### 100.0%###########                                59.6%
# ==> Pouring portable-ruby-3.3.5.arm64_big_sur.bottle.tar.gz
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# afl++               flang               libparserutils      postgresql@17
# aicommit            gptme               lld                 probe-rs-tools
# argtable3           icu4c@75            m68k-elf-binutils   repopack
# binsider            inchi               m68k-elf-gcc        roxctl
# blisp               jikken              maeparser           rsgain
# coordgen            jxl-oxide           openapi-diff        setconf
# crossplane          keep-sorted         oxlint              sysprof
# djlint              libcss              paperjam            tllist
# dug                 libdom              pipet               tmux-sessionizer
# facad               libhubbub           polkit              wthrr
# ==> New Casks
# ccstudio                                 font-suse
# colemak-dh                               fujifilm-tether-app
# colemak-dhk                              furtherance
# excalidrawz                              homerow
# font-bungee-tint                         keyguard
# font-edu-au-vic-wa-nt-arrows             label-live
# font-edu-au-vic-wa-nt-dots               localsend
# font-edu-au-vic-wa-nt-guides             microsoft-edge@canary
# font-edu-au-vic-wa-nt-pre                minstaller
# font-funnel-display                      pixel-shift-combiner
# font-funnel-sans                         rouvy
# font-matemasie                           sanctum
# font-moderustic                          silhouette-studio
# font-new-amsterdam                       synology-image-assistant
# font-noto-serif-todhri                   typefully
# font-rounded-mplus                       vienna-assistant
# font-sour-gummy                          windows-app
#
# You have 39 outdated formulae installed.
#
# ffmpeg 7.0.2_1 is already installed but outdated (so it will be upgraded).
# ==> Downloading https://ghcr.io/v2/homebrew/core/ffmpeg/manifests/7.1
# ######################################################################### 100.0%
# ==> Fetching dependencies for ffmpeg: jpeg-turbo, libtiff, ca-certificates, python-packaging, glib, icu4c@75, harfbuzz, fribidi and libarchive
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/manifests/3.0.4
# ######################################################################### 100.0%
# ==> Fetching jpeg-turbo
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/blobs/sha256:e936777
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/manifests/4.7.0
# ######################################################################### 100.0%
# ==> Fetching libtiff
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/blobs/sha256:90bc1ab873
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ca-certificates/manifests/2024-
# ######################################################################### 100.0%
# ==> Fetching ca-certificates
# ==> Downloading https://ghcr.io/v2/homebrew/core/ca-certificates/blobs/sha256:21
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/python-packaging/manifests/24.1
# ######################################################################### 100.0%
# ==> Fetching python-packaging
# ==> Downloading https://ghcr.io/v2/homebrew/core/python-packaging/blobs/sha256:7
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/manifests/2.82.1
# ######################################################################### 100.0%
# ==> Fetching glib
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/blobs/sha256:be85658ed18ee
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/75/manifests/75.1
# ######################################################################### 100.0%
# ==> Fetching icu4c@75
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/75/blobs/sha256:3da9b88cf
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/manifests/10.0.1_1
# ######################################################################### 100.0%
# ==> Fetching dependencies for harfbuzz: xz and python@3.12
# ==> Downloading https://ghcr.io/v2/homebrew/core/xz/manifests/5.6.3
# ######################################################################### 100.0%
# ==> Fetching xz
# ==> Downloading https://ghcr.io/v2/homebrew/core/xz/blobs/sha256:c54997c6e29b576
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/python/3.12/manifests/3.12.7
# ######################################################################### 100.0%
# ==> Fetching python@3.12
# ==> Downloading https://ghcr.io/v2/homebrew/core/python/3.12/blobs/sha256:d0e1fe
# ######################################################################### 100.0%
# ==> Fetching harfbuzz
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/blobs/sha256:385db0258
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fribidi/manifests/1.0.16
# ######################################################################### 100.0%
# ==> Fetching fribidi
# ==> Downloading https://ghcr.io/v2/homebrew/core/fribidi/blobs/sha256:0b03218a59
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libarchive/manifests/3.7.6
# ######################################################################### 100.0%
# ==> Fetching libarchive
# ==> Downloading https://ghcr.io/v2/homebrew/core/libarchive/blobs/sha256:6c846b3
# ######################################################################### 100.0%
# ==> Fetching ffmpeg
# ==> Downloading https://ghcr.io/v2/homebrew/core/ffmpeg/blobs/sha256:d954df5c7e6
# ######################################################################### 100.0%
# ==> Upgrading ffmpeg
#   7.0.2_1 -> 7.1
# ==> Installing dependencies for ffmpeg: jpeg-turbo, libtiff, ca-certificates, python-packaging, glib, icu4c@75, harfbuzz, fribidi and libarchive
# ==> Installing ffmpeg dependency: jpeg-turbo
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/manifests/3.0.4
# Already downloaded: /Users/jenni/Library/Caches/Homebrew/downloads/2a3630ffd65db74be2c3c6104929548e1a0e8f2c82583e0732016f49b52b2c13--jpeg-turbo-3.0.4.bottle_manifest.json
# ==> Pouring jpeg-turbo--3.0.4.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/jpeg-turbo/3.0.4: 45 files, 3.4MB
# ==> Installing ffmpeg dependency: libtiff
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/manifests/4.7.0
# Already downloaded: /Users/jenni/Library/Caches/Homebrew/downloads/fcbf8df89b7dff054d1f02a8da056c581561fd44a924ae82139fd48a14b994b5--libtiff-4.7.0.bottle_manifest.json
# ==> Pouring libtiff--4.7.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libtiff/4.7.0: 486 files, 8.5MB
# ==> Installing ffmpeg dependency: ca-certificates
# ==> Downloading https://ghcr.io/v2/homebrew/core/ca-certificates/manifests/2024-
# Already downloaded: /Users/jenni/Library/Caches/Homebrew/downloads/338dad7c2ff7c822cda7c417944521589856741c0fbd7a7f07b88a18d7fb7e05--ca-certificates-2024-09-24.bottle_manifest.json
# ==> Pouring ca-certificates--2024-09-24.all.bottle.tar.gz
# ==> Regenerating CA certificate bundle from keychain, this may take a while...
# 🍺  /opt/homebrew/Cellar/ca-certificates/2024-09-24: 4 files, 237.4KB
# ==> Installing ffmpeg dependency: python-packaging
# ==> Downloading https://ghcr.io/v2/homebrew/core/python-packaging/manifests/24.1
# Already downloaded: /Users/jenni/Library/Caches/Homebrew/downloads/cf7e52e1935ea027d95d359754e22e0bbbbf2a04448a71dbb921f7d1be1a015c--python-packaging-24.1-1.bottle_manifest.json
# ==> Pouring python-packaging--24.1.all.bottle.1.tar.gz
# 🍺  /opt/homebrew/Cellar/python-packaging/24.1: 52 files, 374.7KB
# ==> Installing ffmpeg dependency: glib
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/manifests/2.82.1
# Already downloaded: /Users/jenni/Library/Caches/Homebrew/downloads/8eae14bd8879d82f7909b1248fb30efc8327066a3c0dc33f2909c11e49182732--glib-2.82.1.bottle_manifest.json
# ==> Pouring glib--2.82.1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/glib/2.82.1: 504 files, 36.3MB
# ==> Installing ffmpeg dependency: icu4c@75
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/75/manifests/75.1
# Already downloaded: /Users/jenni/Library/Caches/Homebrew/downloads/a44f04ecc59f3f852ae5f4394715b15eda2b4c4afe4792cdd6d2772ae2897aa0--icu4c@75-75.1.bottle_manifest.json
# ==> Pouring icu4c@75--75.1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/icu4c@75/75.1: 277 files, 78.8MB
# ==> Installing ffmpeg dependency: harfbuzz
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/manifests/10.0.1_1
# Already downloaded: /Users/jenni/Library/Caches/Homebrew/downloads/405d668d9b9a117f651d55ceaf9f57ac2f2a2f3a1b0f5d6b8c242d233641fe48--harfbuzz-10.0.1_1.bottle_manifest.json
# ==> Installing dependencies for harfbuzz: xz and python@3.12
# ==> Installing harfbuzz dependency: xz
# ==> Downloading https://ghcr.io/v2/homebrew/core/xz/manifests/5.6.3
# Already downloaded: /Users/jenni/Library/Caches/Homebrew/downloads/e68799185cc17334108ba286ba8c3df0587c9fd8375647d85f7157b62a797599--xz-5.6.3.bottle_manifest.json
# ==> Pouring xz--5.6.3.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/xz/5.6.3: 96 files, 2.0MB
# ==> Installing harfbuzz dependency: python@3.12
# ==> Downloading https://ghcr.io/v2/homebrew/core/python/3.12/manifests/3.12.7
# Already downloaded: /Users/jenni/Library/Caches/Homebrew/downloads/4c58f91c6a7f210a1dd453c7bd895922ce6d9e6b6798fbc72fb21933f3449096--python@3.12-3.12.7.bottle_manifest.json
# ==> Pouring python@3.12--3.12.7.arm64_sonoma.bottle.tar.gz
# ==> /opt/homebrew/Cellar/python@3.12/3.12.7/bin/python3.12 -Im ensurepip
# ==> /opt/homebrew/Cellar/python@3.12/3.12.7/bin/python3.12 -Im pip install -v --
# 🍺  /opt/homebrew/Cellar/python@3.12/3.12.7: 3,264 files, 65.4MB
# ==> Installing harfbuzz
# ==> Pouring harfbuzz--10.0.1_1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/harfbuzz/10.0.1_1: 77 files, 9.7MB
# ==> Installing ffmpeg dependency: fribidi
# ==> Downloading https://ghcr.io/v2/homebrew/core/fribidi/manifests/1.0.16
# Already downloaded: /Users/jenni/Library/Caches/Homebrew/downloads/9b4a81e7d1c2fe7c2d8ed4194565744f65bab0238c00f7f3f521f5aec2b8697f--fribidi-1.0.16.bottle_manifest.json
# ==> Pouring fribidi--1.0.16.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/fribidi/1.0.16: 68 files, 568.0KB
# ==> Installing ffmpeg dependency: libarchive
# ==> Downloading https://ghcr.io/v2/homebrew/core/libarchive/manifests/3.7.6
# Already downloaded: /Users/jenni/Library/Caches/Homebrew/downloads/adc91233352c756d1fac56a60c332eb39f3077ba9513003cff85b49e2bfc26b8--libarchive-3.7.6.bottle_manifest.json
# ==> Pouring libarchive--3.7.6.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libarchive/3.7.6: 65 files, 3.8MB
# ==> Installing ffmpeg
# ==> Pouring ffmpeg--7.1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/ffmpeg/7.1: 287 files, 52.3MB
# ==> Running `brew cleanup ffmpeg`...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# Removing: /opt/homebrew/Cellar/ffmpeg/7.0.2_1... (287 files, 51.8MB)
# Removing: /Users/jenni/Library/Caches/Homebrew/ffmpeg_bottle_manifest--7.0.2_1... (83.1KB)
# Removing: /Users/jenni/Library/Caches/Homebrew/ffmpeg--7.0.2_1... (20.0MB)
# ==> Upgrading 18 dependents of upgraded formulae:
# Disable this behaviour by setting HOMEBREW_NO_INSTALLED_DEPENDENTS_CHECK.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# boost 1.86.0 -> 1.86.0_1, fbthrift 2024.09.02.00 -> 2024.10.07.00, edencommon 2024.09.02.00 -> 2024.10.07.00, fizz 2024.09.02.00 -> 2024.10.07.00, fb303 2024.09.02.00 -> 2024.10.07.00, folly 2024.09.02.00 -> 2024.10.07.00, ghostscript 10.03.1 -> 10.04.0, imagemagick 7.1.1-38 -> 7.1.1-39, jpeg-xl 0.11.0 -> 0.11.0_1, libraw 0.21.2 -> 0.21.3, mvfst 2024.09.02.00 -> 2024.10.07.00, node 22.8.0 -> 22.9.0_1, openjdk 22.0.2 -> 23, pyenv 2.4.12 -> 2.4.14, tesseract 5.4.1 -> 5.4.1_1, unbound 1.21.0 -> 1.21.1, wangle 2024.09.02.00 -> 2024.10.07.00, watchman 2024.09.02.00 -> 2024.10.07.00
# ==> Downloading https://ghcr.io/v2/homebrew/core/openjdk/manifests/23-1
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/boost/manifests/1.86.0_1
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/folly/manifests/2024.10.07.00
# ######################################################################### 100.0%
# ==> Fetching dependencies for folly: boost
# ==> Downloading https://ghcr.io/v2/homebrew/core/boost/manifests/1.86.0_1
# Already downloaded: /Users/jenni/Library/Caches/Homebrew/downloads/0d857a8bc2e9dc402404a7f934e347780757b65327334974cc7bae093a359f1a--boost-1.86.0_1.bottle_manifest.json
# ==> Fetching boost
# ==> Downloading https://ghcr.io/v2/homebrew/core/boost/blobs/sha256:70a85cfceb6b
# ######################################################################### 100.0%
# ==> Fetching folly
# ==> Downloading https://ghcr.io/v2/homebrew/core/folly/blobs/sha256:118e938ec94f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fizz/manifests/2024.10.07.00
# ######################################################################### 100.0%
# ==> Fetching fizz
# ==> Downloading https://ghcr.io/v2/homebrew/core/fizz/blobs/sha256:c104d443aafe4
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/mvfst/manifests/2024.10.07.00
# ######################################################################### 100.0%
# ==> Fetching mvfst
# ==> Downloading https://ghcr.io/v2/homebrew/core/mvfst/blobs/sha256:dcdf0971a7f2
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/wangle/manifests/2024.10.07.00
# ######################################################################### 100.0%
# ==> Fetching wangle
# ==> Downloading https://ghcr.io/v2/homebrew/core/wangle/blobs/sha256:6647927fdf7
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fbthrift/manifests/2024.10.07.0
# ######################################################################### 100.0%
# ==> Fetching fbthrift
# ==> Downloading https://ghcr.io/v2/homebrew/core/fbthrift/blobs/sha256:6ddea0210
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fb303/manifests/2024.10.07.00
# ######################################################################### 100.0%
# ==> Fetching fb303
# ==> Downloading https://ghcr.io/v2/homebrew/core/fb303/blobs/sha256:726cb796802d
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/edencommon/manifests/2024.10.07
# ######################################################################### 100.0%
# ==> Fetching edencommon
# ==> Downloading https://ghcr.io/v2/homebrew/core/edencommon/blobs/sha256:dd74794
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/tesseract/manifests/5.4.1_1
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ghostscript/manifests/10.04.0
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-xl/manifests/0.11.0_1
# ######################################################################### 100.0%
# ==> Fetching dependencies for jpeg-xl: openexr
# ==> Downloading https://ghcr.io/v2/homebrew/core/openexr/manifests/3.3.0
# ######################################################################### 100.0%
# ==> Fetching openexr
# ==> Downloading https://ghcr.io/v2/homebrew/core/openexr/blobs/sha256:e69ceaeff7
# ######################################################################### 100.0%
# ==> Fetching jpeg-xl
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-xl/blobs/sha256:a5ccfecd1e
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libraw/manifests/0.21.3
# ######################################################################### 100.0%
# ==> Fetching dependencies for libraw: libomp
# ==> Downloading https://ghcr.io/v2/homebrew/core/libomp/manifests/19.1.0
# ######################################################################### 100.0%
# ==> Fetching libomp
# ==> Downloading https://ghcr.io/v2/homebrew/core/libomp/blobs/sha256:e1af2969f3d
# ######################################################################### 100.0%
# ==> Fetching libraw
# ==> Downloading https://ghcr.io/v2/homebrew/core/libraw/blobs/sha256:31667768485
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/imagemagick/manifests/7.1.1-39
# ######################################################################### 100.0%
# ==> Fetching dependencies for imagemagick: ghostscript and libtool
# ==> Downloading https://ghcr.io/v2/homebrew/core/ghostscript/manifests/10.04.0
# Already downloaded: /Users/jenni/Library/Caches/Homebrew/downloads/6a042be6c903dc6755dd87cf75222785ef5950daad0b8d8423c0adc7e6c34438--ghostscript-10.04.0.bottle_manifest.json
# ==> Fetching ghostscript
# ==> Downloading https://ghcr.io/v2/homebrew/core/ghostscript/blobs/sha256:0193b5
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtool/manifests/2.5.3
# ######################################################################### 100.0%
# ==> Fetching libtool
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtool/blobs/sha256:e857244e8c
# ######################################################################### 100.0%
# ==> Fetching imagemagick
# ==> Downloading https://ghcr.io/v2/homebrew/core/imagemagick/blobs/sha256:229eed
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/node/manifests/22.9.0_1
# ######################################################################### 100.0%
# ==> Fetching dependencies for node: libuv
# ==> Downloading https://ghcr.io/v2/homebrew/core/libuv/manifests/1.49.0
# ######################################################################### 100.0%
# ==> Fetching libuv
# ==> Downloading https://ghcr.io/v2/homebrew/core/libuv/blobs/sha256:88e188e5184e
# ######################################################################### 100.0%
# ==> Fetching node
# ==> Downloading https://ghcr.io/v2/homebrew/core/node/blobs/sha256:68dee27224d37
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pyenv/manifests/2.4.14
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/unbound/manifests/1.21.1
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/watchman/manifests/2024.10.07.0
# ######################################################################### 100.0%
# ==> Fetching watchman
# ==> Downloading https://ghcr.io/v2/homebrew/core/watchman/blobs/sha256:810fd1ed2
# ######################################################################### 100.0%
# ==> Upgrading folly
#   2024.09.02.00 -> 2024.10.07.00
# ==> Installing dependencies for folly: boost
# ==> Installing folly dependency: boost
# ==> Downloading https://ghcr.io/v2/homebrew/core/boost/manifests/1.86.0_1
# Already downloaded: /Users/jenni/Library/Caches/Homebrew/downloads/0d857a8bc2e9dc402404a7f934e347780757b65327334974cc7bae093a359f1a--boost-1.86.0_1.bottle_manifest.json
# ==> Pouring boost--1.86.0_1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/boost/1.86.0_1: 16,215 files, 521.9MB
# ==> Installing folly
# ==> Pouring folly--2024.10.07.00.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/folly/2024.10.07.00: 1,096 files, 27.7MB
# ==> Running `brew cleanup folly`...
# Removing: /opt/homebrew/Cellar/folly/2024.09.02.00... (1,091 files, 27.6MB)
# Removing: /Users/jenni/Library/Caches/Homebrew/folly_bottle_manifest--2024.09.02.00... (20.1KB)
# ==> Upgrading fizz
#   2024.09.02.00 -> 2024.10.07.00
# ==> Pouring fizz--2024.10.07.00.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/fizz/2024.10.07.00: 204 files, 3.8MB
# ==> Running `brew cleanup fizz`...
# Removing: /opt/homebrew/Cellar/fizz/2024.09.02.00... (213 files, 3.9MB)
# Removing: /Users/jenni/Library/Caches/Homebrew/fizz_bottle_manifest--2024.09.02.00... (21.3KB)
# ==> Upgrading mvfst
#   2024.09.02.00 -> 2024.10.07.00
# ==> Pouring mvfst--2024.10.07.00.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/mvfst/2024.10.07.00: 285 files, 8MB
# ==> Running `brew cleanup mvfst`...
# Removing: /opt/homebrew/Cellar/mvfst/2024.09.02.00... (282 files, 8MB)
# Removing: /Users/jenni/Library/Caches/Homebrew/mvfst_bottle_manifest--2024.09.02.00... (21.4KB)
# ==> Upgrading wangle
#   2024.09.02.00 -> 2024.10.07.00
# ==> Pouring wangle--2024.10.07.00.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/wangle/2024.10.07.00: 119 files, 3.4MB
# ==> Running `brew cleanup wangle`...
# Removing: /opt/homebrew/Cellar/wangle/2024.09.02.00... (119 files, 3.4MB)
# Removing: /Users/jenni/Library/Caches/Homebrew/wangle_bottle_manifest--2024.09.02.00... (21.8KB)
# ==> Upgrading fbthrift
#   2024.09.02.00 -> 2024.10.07.00
# ==> Pouring fbthrift--2024.10.07.00.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/fbthrift/2024.10.07.00: 881 files, 28MB
# ==> Running `brew cleanup fbthrift`...
# Removing: /opt/homebrew/Cellar/fbthrift/2024.09.02.00... (844 files, 27.2MB)
# Removing: /Users/jenni/Library/Caches/Homebrew/fbthrift_bottle_manifest--2024.09.02.00... (24.0KB)
# ==> Upgrading fb303
#   2024.09.02.00 -> 2024.10.07.00
# ==> Pouring fb303--2024.10.07.00.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/fb303/2024.10.07.00: 58 files, 3.7MB
# ==> Running `brew cleanup fb303`...
# Removing: /opt/homebrew/Cellar/fb303/2024.09.02.00... (58 files, 3.7MB)
# Removing: /Users/jenni/Library/Caches/Homebrew/fb303_bottle_manifest--2024.09.02.00... (24.5KB)
# ==> Upgrading edencommon
#   2024.09.02.00 -> 2024.10.07.00
# ==> Pouring edencommon--2024.10.07.00.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/edencommon/2024.10.07.00: 79 files, 1.8MB
# ==> Running `brew cleanup edencommon`...
# Removing: /opt/homebrew/Cellar/edencommon/2024.09.02.00... (78 files, 1.8MB)
# Removing: /Users/jenni/Library/Caches/Homebrew/edencommon_bottle_manifest--2024.09.02.00... (25.5KB)
# ==> Upgrading jpeg-xl
#   0.11.0 -> 0.11.0_1
# ==> Installing dependencies for jpeg-xl: openexr
# ==> Installing jpeg-xl dependency: openexr
# ==> Downloading https://ghcr.io/v2/homebrew/core/openexr/manifests/3.3.0
# Already downloaded: /Users/jenni/Library/Caches/Homebrew/downloads/9a7d1471fdc12827fcd5bfbd5e6006c713a8ff6407941e7d7193cadd3c0b56eb--openexr-3.3.0.bottle_manifest.json
# ==> Pouring openexr--3.3.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/openexr/3.3.0: 210 files, 6.2MB
# ==> Installing jpeg-xl
# ==> Pouring jpeg-xl--0.11.0_1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/jpeg-xl/0.11.0_1: 64 files, 32.4MB
# ==> Running `brew cleanup jpeg-xl`...
# Removing: /opt/homebrew/Cellar/jpeg-xl/0.11.0... (64 files, 32.4MB)
# Removing: /Users/jenni/Library/Caches/Homebrew/jpeg-xl_bottle_manifest--0.11.0... (20.8KB)
# Removing: /Users/jenni/Library/Caches/Homebrew/jpeg-xl--0.11.0... (13.4MB)
# ==> Upgrading libraw
#   0.21.2 -> 0.21.3
# ==> Installing dependencies for libraw: libomp
# ==> Installing libraw dependency: libomp
# ==> Downloading https://ghcr.io/v2/homebrew/core/libomp/manifests/19.1.0
# Already downloaded: /Users/jenni/Library/Caches/Homebrew/downloads/9922ad6522f937c029f3a8bdcc60b4ba08a5ec62f8d30da4efb0dbdf8b788e9b--libomp-19.1.0.bottle_manifest.json
# ==> Pouring libomp--19.1.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libomp/19.1.0: 9 files, 1.7MB
# ==> Installing libraw
# ==> Pouring libraw--0.21.3.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libraw/0.21.3: 74 files, 6.0MB
# ==> Running `brew cleanup libraw`...
# Removing: /opt/homebrew/Cellar/libraw/0.21.2... (74 files, 5.9MB)
# ==> Upgrading imagemagick
#   7.1.1-38 -> 7.1.1-39
# ==> Installing dependencies for imagemagick: ghostscript and libtool
# ==> Installing imagemagick dependency: ghostscript
# ==> Downloading https://ghcr.io/v2/homebrew/core/ghostscript/manifests/10.04.0
# Already downloaded: /Users/jenni/Library/Caches/Homebrew/downloads/6a042be6c903dc6755dd87cf75222785ef5950daad0b8d8423c0adc7e6c34438--ghostscript-10.04.0.bottle_manifest.json
# ==> Pouring ghostscript--10.04.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/ghostscript/10.04.0: 640 files, 122MB
# ==> Installing imagemagick dependency: libtool
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtool/manifests/2.5.3
# Already downloaded: /Users/jenni/Library/Caches/Homebrew/downloads/a3fb370c644cf73593e4df8b5c40f2ccb0459d57248d95aba050def3c96414ad--libtool-2.5.3.bottle_manifest.json
# ==> Pouring libtool--2.5.3.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libtool/2.5.3: 76 files, 3.9MB
# ==> Installing imagemagick
# ==> Pouring imagemagick--7.1.1-39.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/imagemagick/7.1.1-39: 808 files, 32.3MB
# ==> Running `brew cleanup imagemagick`...
# Removing: /opt/homebrew/Cellar/imagemagick/7.1.1-38... (808 files, 32.4MB)
# Removing: /Users/jenni/Library/Caches/Homebrew/imagemagick_bottle_manifest--7.1.1-38... (98.2KB)
# Removing: /Users/jenni/Library/Caches/Homebrew/imagemagick_bottle_manifest--7.1.1-38_1... (84.9KB)
# ==> Upgrading node
#   22.8.0 -> 22.9.0_1
# ==> Installing dependencies for node: libuv
# ==> Installing node dependency: libuv
# ==> Downloading https://ghcr.io/v2/homebrew/core/libuv/manifests/1.49.0
# Already downloaded: /Users/jenni/Library/Caches/Homebrew/downloads/04deb061e3809a68a4906b05430dd75d583aa5b412f1513cff0767c31a4f771f--libuv-1.49.0.bottle_manifest.json
# ==> Pouring libuv--1.49.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libuv/1.49.0: 20 files, 1.2MB
# ==> Installing node
# ==> Pouring node--22.9.0_1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/node/22.9.0_1: 2,066 files, 78.6MB
# ==> Running `brew cleanup node`...
# Removing: /opt/homebrew/Cellar/node/22.8.0... (2,058 files, 79.6MB)
# Removing: /Users/jenni/Library/Caches/Homebrew/node_bottle_manifest--22.8.0... (18.8KB)
# ==> Upgrading watchman
#   2024.09.02.00 -> 2024.10.07.00
# ==> Pouring watchman--2024.10.07.00.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/watchman/2024.10.07.00: 26 files, 13.8MB
# ==> Running `brew cleanup watchman`...
# Removing: /opt/homebrew/Cellar/watchman/2024.09.02.00... (26 files, 13.3MB)
# Removing: /Users/jenni/Library/Caches/Homebrew/watchman_bottle_manifest--2024.09.02.00... (33.3KB)
# ==> Checking for dependents of upgraded formulae...
# ==> No broken dependents found!

# %% [markdown]
# Import audio split function from pydub

# %%
from pydub import AudioSegment

# %% [markdown]
# This function takes 3 inputs:
# 1. The audio file that is to be split up
# 2. A list of integers which shows when each ad starts and ends. The list must be an even length to include the in and out time of each ad.
# 3. the name of the podcast, to be used in the final file output name

# %% [markdown]
# *IMPORTANT* Before running this, make sure that your mp3 file is saved in the same folder. You may need to copy this in your raw_data folder

# %%
def split_filemp3(original_file, ad_list, podcast_name):

    #import original_file
    new_audio = AudioSegment.from_mp3(original_file)

    #save duration
    duration = int(new_audio.duration_seconds)

    #set default to no_ad
    is_ad = '0'

    #if the ad_list doesn't start with 0, then the ads don't start straight away.
    #in this case, insert '0' first in the list so that a segment is created at the start.
    if ad_list[0] != 0:
        ad_list.insert(0, 0)
        is_ad = '1'
    #add duration at the end so that the end segments can be made.
    if ad_list[-1] != duration:
        ad_list.append(duration)
    #Go through each segement in the list, label whether the section is an ad or not
    for index in range(0,len(ad_list)-1):
        start = ad_list[index]
        end = ad_list[index+1]
        if is_ad == '1':
            is_ad = '0'
        else:
            is_ad = '1'
        #go through each second in the segment and create a new 5 second clip from here.
        #stop before the end of the segment so that only 5 second clips are created
        for tc in range(start, (end-4)):
            start_clip = tc*1000 #pydub works with milliseconds, so seconds are converted here
            end_clip = (tc+5)*1000
            new_audio[start_clip:end_clip].export(
                f'{podcast_name}_{is_ad}_{tc}.wav',
                format='wav')
    is_ad = '0'
    return 'finished'

# %% [markdown]
# Same function but for wav files, outputs mp3 to be consistent

# %%
def split_filewav(original_file, ad_list, podcast_name):

    #import original_file
    new_audio = AudioSegment.from_wav(original_file)

    #save duration
    duration = int(new_audio.duration_seconds)

    #set default to no_ad
    is_ad = '0'

    #if the ad_list doesn't start with 0, then the ads don't start straight away.
    #in this case, insert '0' first in the list so that a segment is created at the start.
    if ad_list[0] != 0:
        ad_list.insert(0, 0)
        is_ad = '1'
    #add duration at the end so that the end segments can be made.
    if ad_list[-1] != duration:
        ad_list.append(duration)
    #Go through each segement in the list, label whether the section is an ad or not
    for index in range(0,len(ad_list)-1):
        start = ad_list[index]
        end = ad_list[index+1]
        if is_ad == '1':
            is_ad = '0'
        else:
            is_ad = '1'
        #go through each second in the segment and create a new 5 second clip from here.
        #stop before the end of the segment so that only 5 second clips are created
        for tc in range(start, (end-4)):
            start_clip = tc*1000 #pydub works with milliseconds, so seconds are converted here
            end_clip = (tc+5)*1000
            new_audio[start_clip:end_clip].export(
                f'{podcast_name}_{is_ad}_{tc}.wav',
                format='wav')
    is_ad = '0'
    return 'finished'
